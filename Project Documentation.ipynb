# %% [markdown]
# # Assessment Task 3 Documentation
# ## Phase 1: Identifying and Defining
# #### Introduction
# In this project, you'll navigate the complete data analysis process, from defining the problem to presenting your
# findings. This project offers invaluable practical experience with real-world data and various data analysis tools. By
# the end, you'll have developed a robust skill set in data analysis and advanced Python.
#
# This project will take you through the entire process of conducting a data analysis, from defining the problem to
# presenting your findings. You'll gain practical experience in handling real-world data and using various tools and
# technologies.
#
# Design Brief: Identify a complex societal issue (e.g. housing, natural disasters) or a need within the school community. Form a hypothesis related to the issue. Design a system that processes and visualises data to test your hypothesis.
#
#
# #### Requirements Outline
# Functional:
# - Needs to display information about train delays clearly
# - Have all information including the types of trains, area, etc.
#
# Non-Functional:
# - Make sure it is aesthetically pleasing
# - Display info in graph
#
#
# #### Define Your Purpose:
# "Are people commuting on trains experiencing more delays than ever."
#
#
# #### Three Tiered Map:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Phase 2: Researching and Planning
# #### What's already available on this topic?
# https://www.transport.nsw.gov.au/data-and-research/data-and-insights/sydney-trains-and-nsw-trainlink-intercity-performance-reports Contains dataset of the punctuality of trains from 2020 - present date, alongside reasons towards train delays.
#
# https://www.theguardian.com/australia-news/2025/jul/24/nearly-one-in-five-nsw-trains-ran-late-in-past-year-falling-well-short-of-own-performance-target-data-shows Relates train delays in 2025 to government decisions.
#
# https://www.transport.nsw.gov.au/data-and-research/data-and-insights/new-customer-on-time-measure-%E2%80%93-measuring-our-customer%E2%80%99s?utm_
#
#
# #### SEE-I Paragraph
# The punctuality of trains in NSW is on a steady decline of being punctual based on the data that I have collected from these three websites. It is clear that a couple years ago, the average punctuality was much higher than in recent years. From 2019 - 2022, the average amount of trains on time was 92.98 percent, however, from 2023 - 2025, the average was only 85.97 percent. This relates to my question where I explore the idea that people nowadays are experiencing more delays than ever.
#
# #### Data Dictionary
# | **Field Name**      | **Data Type** | **Description**                                              | **Example Value** | **Constraints / Notes**                                      |
# |---------------------|---------------|--------------------------------------------------------------|-------------------|---------------------------------------------------------------|
# | date              | Integer         | Date of reporting                                             | March 2024        | Only monthly and Yearly data                                 |
# | service           | String        | Type of service network                                       | Suburban          | Either Suburban or Intercity                                     |
# | punctuality       | Float         | % of trains arriving within 5/6 minutes of schedule           | 82.5              | Value between 0 and 100                                       |
# | delay             | Float         | % of trains that were late                                    | 17.5              | Complement of punctuality                                     |
# | reporting_period  | String        | Monthly or Yearly data                                        | Month                                     | Limited                               |
# | line              | String        | Area where train is running(line)                             | T2              |Tell user where line runs                                       |

# %% [markdown]
# ## Phase 4
# #### Analyse and Conclude:
# My code does an excellent job in displaying the information about NSW train delays, however could possibly benefit from adding a couple things. The code shows both raw data and a graph and gives the user multiple choices about what data they wish to see. A couple improvements could be the additino of different graphs, for example Pie charts and bar graphs, but the line graph in my opinion effectively represents information. Another improvement could be in the monthly graph, I could find a solution to bottom displaying all the dates overlapping eachother. I also cannot find the reason for the graph being backwards which is strange.
#
# #### Testing:
# My code accurately shows all the information without fail and the graphs always come.
#
# #### Peer Verification
# (My mum because I am doing at home)
# Plus: Adding choice of which line user wants to choose
# Minus: Graph is sometimes hard to read in monthly because of too much data
# Implication: Percentage was much higher 3-6 years ago compared to now
#
# #### Evaluation
# Requirements: Marks all the boxes with some extra features on top of that, including the ability to choose what line/region
# Peer Feedback: Fully agree, better time management would get rid of some issues and could see improvements
# Project Management: A more even spread of time working on this project would see better results - not putting it off until the last couple weeks or so
# Data and Security - Security unnecessary as the Transport NSW posted this data online, without stating the obvious decrease of punctuality. Data is valid, accurate and timely as gathered from trusted source.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
